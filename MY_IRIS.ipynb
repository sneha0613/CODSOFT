# %% [markdown]
# <a href="https://colab.research.google.com/github/sneha0613/CODSOFT/blob/main/MY_IRIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv('IRIS.csv')

# %%
 df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
df.shape
# Out:
# (150, 5)

# %%
df.isnull().any()
# Out:
# sepal_length    False
# sepal_width     False
# petal_length    False
# petal_width     False
# species         False
# dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
data=df.isnull().sum().any()
print("is there any null values?",data)
# Out:
# is there any null values? False

# %%
df.duplicated().any()
# Out:
# True

# %%
 dup_data=df.drop_duplicates()
 print(dup_data)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [147 rows x 5 columns]

# %%
df.dropna(axis=0)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [147 rows x 5 columns]

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df['species'].value_counts()
# Out:
# species
# Iris-versicolor    50
# Iris-virginica     49
# Iris-setosa        48
# Name: count, dtype: int64

# %%
df['species'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
fig = plt.figure(figsize=(10,10))
fig_dims=(3,2)

plt.subplot2grid(fig_dims,(0,0))
df['sepal_length'].hist()

plt.subplot2grid(fig_dims,(1,0))
df['sepal_width'].hist()
plt.subplot2grid(fig_dims,(1,1))
df['petal_length'].hist()
plt.subplot2grid(fig_dims,(2,0))
df['petal_width'].hist()
# Out:
# <Axes: >

# %%
sns.barplot(x='species',y='sepal_length',data=df,palette='husl')
# Out:
# <ipython-input-34-eb6b99746a1f>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='species',y='sepal_length',data=df,palette='husl')
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
colors=['red','blue','orange']
sns.pairplot(df,hue='species',palette=colors)

# %%
colours=['red','blue','orange']
Species=['iris-setosa','iris-versicolor','iris-virginica']

# %%
sns.scatterplot(x='sepal_length',y='sepal_width',data=df,hue='species',palette=colours)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.scatterplot(x='petal_length',y='petal_width',data=df,hue='species',palette=colours)
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %%
sns.scatterplot(x='sepal_length',y='petal_length',data=df,hue='species',palette=colours)
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.scatterplot(x='sepal_width',y='petal_width',data=df,hue='species',palette=colours)
# Out:
# <Axes: xlabel='sepal_width', ylabel='petal_width'>

# %%
df.groupby('species')['sepal_length'].mean()
# Out:
# species
# Iris-setosa        5.010417
# Iris-versicolor    5.936000
# Iris-virginica     6.604082
# Name: sepal_length, dtype: float64

# %%
sns.barplot(x='species',y='sepal_length',data=df,palette='husl')
# Out:
# <ipython-input-70-e27722a60276>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='species',y='sepal_length',data=df,palette='husl')
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
df.groupby('species')['sepal_width'].mean()
# Out:
# species
# 0    3.431250
# 1    2.770000
# 2    2.979592
# Name: sepal_width, dtype: float64

# %%
sns.barplot(x='species',y='sepal_width',data=df,palette='husl')
# Out:
# <ipython-input-80-21fe4d958b12>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='species',y='sepal_width',data=df,palette='husl')
# <Axes: xlabel='species', ylabel='sepal_width'>

# %%
df.groupby('species')['petal_length'].mean()
# Out:
# species
# 0    1.462500
# 1    4.260000
# 2    5.561224
# Name: petal_length, dtype: float64

# %%
sns.barplot(x='species',y='petal_length',data=df,palette='husl')
# Out:
# <ipython-input-82-d9585c5161f1>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='species',y='petal_length',data=df,palette='husl')
# <Axes: xlabel='species', ylabel='petal_length'>

# %%
df.groupby('species')['petal_width'].mean()
# Out:
# species
# 0    0.250000
# 1    1.326000
# 2    2.028571
# Name: petal_width, dtype: float64

# %%
sns.barplot(x='species',y='petal_width',data=df,palette='husl')
# Out:
# <ipython-input-84-8d614eb32025>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='species',y='petal_width',data=df,palette='husl')
# <Axes: xlabel='species', ylabel='petal_width'>

# %%
 df_numeric = df.select_dtypes(include=['number'])
df_numeric.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109321      0.871305     0.817058
# sepal_width      -0.109321     1.000000     -0.421057    -0.356376
# petal_length      0.871305    -0.421057      1.000000     0.961883
# petal_width       0.817058    -0.356376      0.961883     1.000000

# %%
corr= df_numeric.corr()
sns.heatmap(corr,annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['species'] = le.fit_transform(df['species'])
df.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0
# 5           5.4          3.9           1.7          0.4        0
# 6           4.6          3.4           1.4          0.3        0
# 7           5.0          3.4           1.5          0.2        0
# 8           4.4          2.9           1.4          0.2        0
# 9           4.9          3.1           1.5          0.1        0

# %%
from sklearn.model_selection import train_test_split
x=df.drop('species',axis=1)
y=df['species']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30)

# %%
#logical regression
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
#print metric to get performance
print("Accuracy:",model.score(x_test,y_test)*100)
# Out:
# Accuracy: 95.55555555555556

# %%
#knn - k-nearest neighbours
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
print("Accuracy:",model.score(x_test,y_test)*100)
# Out:
# Accuracy: 91.11111111111111

# %%
#decision tree
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
print("Accuracy:",model.score(x_test,y_test)*100)
# Out:
# Accuracy: 88.88888888888889
